# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=df7e1a45d4925410a8ba4c0d3e685ca0

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.  Record numbers 1-50 and the set counter - how many sets of 50
record_count = 1
set_count = 1

# Loop through all the cities in the list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes. 
    #If the remainder of the index divided by 50 ==0 and if the index is greater than or equal to 50
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
      
    # Create endpoint URL with each city.  replace blanks with "+" which finds the weather for the city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_desc = city_weather["weather"][0]["description"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dujuma
# City not found. Skipping...
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | takoradi
# Processing Record 7 of Set 1 | sorland
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | manono
# Processing Record 10 of Set 1 | bengkulu
# Processing Record 11 of Set 1 | sur
# Processing Record 12 of Set 1 | alice springs
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | bathsheba
# Processing Record 15 of Set 1 | vila franca do campo
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | chuy
# Processing Record 19 of Set 1 | tazovskiy
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | pangnirtung
# Processing Record 22 of Set 1 | cochrane
# Processing Record 23 of Set 1 | baie-comeau
# Processing Record 24 of Set 1 | riyadh
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | rafai
# Processing Record 27 of Set 1 | kjollefjord
# Processing Record 28 of Set 1 | isangel
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | hire
# City not found. Skipping...
# Processing Record 31 of Set 1 | vicuna
# Processing Record 32 of Set 1 | bilibino
# Processing Record 33 of Set 1 | belcista
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | carlsbad
# Processing Record 36 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 1 | iquique
# Processing Record 38 of Set 1 | khatanga
# Processing Record 39 of Set 1 | lukovetskiy
# Processing Record 40 of Set 1 | adamas
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | hami
# Processing Record 43 of Set 1 | port hawkesbury
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | dali
# Processing Record 46 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 1 | poum
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | zhengjiatun
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | port moresby
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | forestville
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | christchurch
# Processing Record 8 of Set 2 | tiksi
# Processing Record 9 of Set 2 | sao filipe
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | chingirlau
# Processing Record 13 of Set 2 | wamba
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | yarmouth
# Processing Record 16 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 2 | chimbote
# Processing Record 18 of Set 2 | ahtopol
# Processing Record 19 of Set 2 | katsuura
# Processing Record 20 of Set 2 | le mars
# Processing Record 21 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 2 | acapulco
# Processing Record 23 of Set 2 | kerewan
# Processing Record 24 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 25 of Set 2 | loralai
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | nikolskoye
# Processing Record 28 of Set 2 | klaksvik
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | shunyi
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | nizhniy tsasuchey
# Processing Record 35 of Set 2 | komsomolskiy
# Processing Record 36 of Set 2 | padang
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | avarua
# Processing Record 39 of Set 2 | praya
# Processing Record 40 of Set 2 | kokopo
# Processing Record 41 of Set 2 | lavrentiya
# Processing Record 42 of Set 2 | nantucket
# Processing Record 43 of Set 2 | qaanaaq
# Processing Record 44 of Set 2 | port blair
# Processing Record 45 of Set 2 | bontang
# Processing Record 46 of Set 2 | abha
# Processing Record 47 of Set 2 | ust-kuyga
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | svetlyy
# Processing Record 50 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 3 | pueblo nuevo
# Processing Record 2 of Set 3 | porto-vecchio
# Processing Record 3 of Set 3 | bara
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | castro
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | mehamn
# Processing Record 8 of Set 3 | providencia
# Processing Record 9 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | pyapon
# Processing Record 13 of Set 3 | salalah
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | dikson
# Processing Record 16 of Set 3 | tura
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | redmond
# Processing Record 19 of Set 3 | belfast
# Processing Record 20 of Set 3 | pisco
# Processing Record 21 of Set 3 | matadi
# Processing Record 22 of Set 3 | haapiti
# Processing Record 23 of Set 3 | atuona
# Processing Record 24 of Set 3 | auki
# Processing Record 25 of Set 3 | hilo
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | albany
# Processing Record 28 of Set 3 | cherskiy
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | rio claro
# Processing Record 31 of Set 3 | sistranda
# Processing Record 32 of Set 3 | mopipi
# Processing Record 33 of Set 3 | souillac
# Processing Record 34 of Set 3 | saint-denis
# Processing Record 35 of Set 3 | goderich
# Processing Record 36 of Set 3 | bethel
# Processing Record 37 of Set 3 | tilichiki
# Processing Record 38 of Set 3 | kalasin
# Processing Record 39 of Set 3 | husavik
# Processing Record 40 of Set 3 | mizdah
# Processing Record 41 of Set 3 | san cristobal
# Processing Record 42 of Set 3 | roald
# Processing Record 43 of Set 3 | inhambane
# Processing Record 44 of Set 3 | poya
# Processing Record 45 of Set 3 | narsaq
# Processing Record 46 of Set 3 | colwyn bay
# Processing Record 47 of Set 3 | alofi
# Processing Record 48 of Set 3 | hambantota
# Processing Record 49 of Set 3 | viedma
# Processing Record 50 of Set 3 | hermanus
# Processing Record 1 of Set 4 | tandil
# Processing Record 2 of Set 4 | fecamp
# Processing Record 3 of Set 4 | osakarovka
# Processing Record 4 of Set 4 | wanaka
# Processing Record 5 of Set 4 | aden
# Processing Record 6 of Set 4 | taga
# Processing Record 7 of Set 4 | richards bay
# Processing Record 8 of Set 4 | ayaviri
# Processing Record 9 of Set 4 | sola
# Processing Record 10 of Set 4 | korla
# Processing Record 11 of Set 4 | acarau
# Processing Record 12 of Set 4 | pauini
# Processing Record 13 of Set 4 | cockburn town
# Processing Record 14 of Set 4 | clyde river
# Processing Record 15 of Set 4 | banes
# Processing Record 16 of Set 4 | kathmandu
# Processing Record 17 of Set 4 | cascais
# Processing Record 18 of Set 4 | brae
# Processing Record 19 of Set 4 | izyaslav
# Processing Record 20 of Set 4 | carhuamayo
# Processing Record 21 of Set 4 | east london
# Processing Record 22 of Set 4 | arraial do cabo
# Processing Record 23 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 4 | perigueux
# Processing Record 25 of Set 4 | santa fe
# Processing Record 26 of Set 4 | geraldton
# Processing Record 27 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 4 | vestmannaeyjar
# Processing Record 29 of Set 4 | lorut
# Processing Record 30 of Set 4 | embu
# Processing Record 31 of Set 4 | ilulissat
# Processing Record 32 of Set 4 | palmer
# Processing Record 33 of Set 4 | abonnema
# Processing Record 34 of Set 4 | coihaique
# Processing Record 35 of Set 4 | tiznit
# Processing Record 36 of Set 4 | faanui
# Processing Record 37 of Set 4 | axim
# Processing Record 38 of Set 4 | srandakan
# Processing Record 39 of Set 4 | bandarbeyla
# Processing Record 40 of Set 4 | zavitinsk
# Processing Record 41 of Set 4 | cape town
# Processing Record 42 of Set 4 | gizo
# Processing Record 43 of Set 4 | one hundred mile house
# City not found. Skipping...
# Processing Record 44 of Set 4 | chulman
# Processing Record 45 of Set 4 | ulladulla
# Processing Record 46 of Set 4 | standerton
# Processing Record 47 of Set 4 | maniitsoq
# Processing Record 48 of Set 4 | pemangkat
# Processing Record 49 of Set 4 | copiapo
# Processing Record 50 of Set 4 | jamestown
# Processing Record 1 of Set 5 | muros
# Processing Record 2 of Set 5 | saldanha
# Processing Record 3 of Set 5 | leua
# Processing Record 4 of Set 5 | tatarsk
# Processing Record 5 of Set 5 | skagen
# Processing Record 6 of Set 5 | mogadishu
# Processing Record 7 of Set 5 | flin flon
# Processing Record 8 of Set 5 | uchiza
# Processing Record 9 of Set 5 | grindavik
# Processing Record 10 of Set 5 | kuah
# Processing Record 11 of Set 5 | whitehorse
# Processing Record 12 of Set 5 | iqaluit
# Processing Record 13 of Set 5 | waingapu
# Processing Record 14 of Set 5 | orbetello
# Processing Record 15 of Set 5 | kavieng
# Processing Record 16 of Set 5 | tanshui
# City not found. Skipping...
# Processing Record 17 of Set 5 | kanlagay
# Processing Record 18 of Set 5 | nishihara
# Processing Record 19 of Set 5 | leninskoye
# Processing Record 20 of Set 5 | itarema
# Processing Record 21 of Set 5 | soyo
# Processing Record 22 of Set 5 | omboue
# Processing Record 23 of Set 5 | norman wells
# Processing Record 24 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 5 | nanortalik
# Processing Record 26 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 5 | nogliki
# Processing Record 28 of Set 5 | la ronge
# Processing Record 29 of Set 5 | hamilton
# Processing Record 30 of Set 5 | victoria
# Processing Record 31 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 5 | merauke
# Processing Record 33 of Set 5 | krasnoselkup
# Processing Record 34 of Set 5 | taree
# Processing Record 35 of Set 5 | yellowknife
# Processing Record 36 of Set 5 | jonkoping
# Processing Record 37 of Set 5 | toro
# Processing Record 38 of Set 5 | linxia
# Processing Record 39 of Set 5 | antalaha
# Processing Record 40 of Set 5 | nelson bay
# Processing Record 41 of Set 5 | kalabo
# Processing Record 42 of Set 5 | kodiak
# Processing Record 43 of Set 5 | georgetown
# Processing Record 44 of Set 5 | umm kaddadah
# Processing Record 45 of Set 5 | saskylakh
# Processing Record 46 of Set 5 | mandalgovi
# Processing Record 47 of Set 5 | muscat
# Processing Record 48 of Set 5 | cidreira
# Processing Record 49 of Set 5 | suifenhe
# Processing Record 50 of Set 5 | phuket
# Processing Record 1 of Set 6 | chalons-en-champagne
# Processing Record 2 of Set 6 | fukue
# Processing Record 3 of Set 6 | saint george
# Processing Record 4 of Set 6 | kungurtug
# Processing Record 5 of Set 6 | ponta delgada
# Processing Record 6 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 6 | ust-maya
# Processing Record 8 of Set 6 | clayton
# Processing Record 9 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 6 | san rafael
# Processing Record 12 of Set 6 | kitimat
# Processing Record 13 of Set 6 | adrar
# Processing Record 14 of Set 6 | niono
# Processing Record 15 of Set 6 | montrose
# Processing Record 16 of Set 6 | namibe
# Processing Record 17 of Set 6 | faya
# Processing Record 18 of Set 6 | saint-francois
# Processing Record 19 of Set 6 | tocache
# Processing Record 20 of Set 6 | marystown
# Processing Record 21 of Set 6 | mount isa
# Processing Record 22 of Set 6 | caconda
# Processing Record 23 of Set 6 | ossora
# Processing Record 24 of Set 6 | lompoc
# Processing Record 25 of Set 6 | guerrero negro
# Processing Record 26 of Set 6 | umm lajj
# Processing Record 27 of Set 6 | harper
# Processing Record 28 of Set 6 | namatanai
# Processing Record 29 of Set 6 | chatellerault
# Processing Record 30 of Set 6 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 31 of Set 6 | uaua
# Processing Record 32 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 6 | kahului
# Processing Record 34 of Set 6 | provideniya
# Processing Record 35 of Set 6 | chapais
# Processing Record 36 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 6 | pryazha
# Processing Record 38 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 6 | kutum
# Processing Record 40 of Set 6 | assela
# City not found. Skipping...
# Processing Record 41 of Set 6 | san pedro
# Processing Record 42 of Set 6 | broome
# Processing Record 43 of Set 6 | harwich
# Processing Record 44 of Set 6 | ati
# Processing Record 45 of Set 6 | chegem
# Processing Record 46 of Set 6 | darnah
# Processing Record 47 of Set 6 | ayagoz
# Processing Record 48 of Set 6 | baghdad
# Processing Record 49 of Set 6 | morros
# Processing Record 50 of Set 6 | ancud
# Processing Record 1 of Set 7 | sorong
# Processing Record 2 of Set 7 | ajdabiya
# Processing Record 3 of Set 7 | san felipe
# Processing Record 4 of Set 7 | betong
# Processing Record 5 of Set 7 | awbari
# Processing Record 6 of Set 7 | mpongwe
# Processing Record 7 of Set 7 | pavlogradka
# Processing Record 8 of Set 7 | ewa beach
# Processing Record 9 of Set 7 | oksfjord
# Processing Record 10 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 7 | sitka
# Processing Record 12 of Set 7 | belmonte
# Processing Record 13 of Set 7 | erenhot
# Processing Record 14 of Set 7 | beringovskiy
# Processing Record 15 of Set 7 | peniche
# Processing Record 16 of Set 7 | minab
# Processing Record 17 of Set 7 | nanakuli
# Processing Record 18 of Set 7 | deputatskiy
# Processing Record 19 of Set 7 | gravdal
# Processing Record 20 of Set 7 | tautira
# Processing Record 21 of Set 7 | constitucion
# Processing Record 22 of Set 7 | wencheng
# Processing Record 23 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 7 | college
# Processing Record 25 of Set 7 | parras
# City not found. Skipping...
# Processing Record 26 of Set 7 | saint-pierre
# Processing Record 27 of Set 7 | tezu
# Processing Record 28 of Set 7 | praia da vitoria
# Processing Record 29 of Set 7 | hithadhoo
# Processing Record 30 of Set 7 | oyon
# Processing Record 31 of Set 7 | mizan teferi
# Processing Record 32 of Set 7 | buala
# Processing Record 33 of Set 7 | parral
# Processing Record 34 of Set 7 | komsomolskoye
# Processing Record 35 of Set 7 | payo
# Processing Record 36 of Set 7 | northam
# Processing Record 37 of Set 7 | danville
# Processing Record 38 of Set 7 | granada
# Processing Record 39 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 40 of Set 7 | nosy varika
# Processing Record 41 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 7 | chowchilla
# Processing Record 43 of Set 7 | mount gambier
# Processing Record 44 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 45 of Set 7 | portland
# Processing Record 46 of Set 7 | hofn
# Processing Record 47 of Set 7 | kinablangan
# Processing Record 48 of Set 7 | kryve ozero
# Processing Record 49 of Set 7 | wenling
# Processing Record 50 of Set 7 | acari
# Processing Record 1 of Set 8 | turan
# Processing Record 2 of Set 8 | biak
# Processing Record 3 of Set 8 | sahuaripa
# Processing Record 4 of Set 8 | pevek
# Processing Record 5 of Set 8 | aswan
# Processing Record 6 of Set 8 | opuwo
# Processing Record 7 of Set 8 | omsukchan
# Processing Record 8 of Set 8 | airai
# Processing Record 9 of Set 8 | alihe
# Processing Record 10 of Set 8 | abu samrah
# Processing Record 11 of Set 8 | beyneu
# Processing Record 12 of Set 8 | talara
# Processing Record 13 of Set 8 | sinnamary
# Processing Record 14 of Set 8 | ucluelet
# Processing Record 15 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 8 | micheweni
# Processing Record 18 of Set 8 | bolama
# Processing Record 19 of Set 8 | upernavik
# Processing Record 20 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 8 | severomuysk
# Processing Record 22 of Set 8 | ambon
# Processing Record 23 of Set 8 | mayo
# Processing Record 24 of Set 8 | camacha
# Processing Record 25 of Set 8 | terrace
# Processing Record 26 of Set 8 | sao paulo de olivenca
# Processing Record 27 of Set 8 | carbonia
# Processing Record 28 of Set 8 | port-cartier
# Processing Record 29 of Set 8 | ilhabela
# Processing Record 30 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 31 of Set 8 | pacific grove
# Processing Record 32 of Set 8 | vaitape
# Processing Record 33 of Set 8 | dawei
# Processing Record 34 of Set 8 | baruun-urt
# Processing Record 35 of Set 8 | port macquarie
# Processing Record 36 of Set 8 | sao miguel do araguaia
# Processing Record 37 of Set 8 | henderson
# Processing Record 38 of Set 8 | tacoronte
# Processing Record 39 of Set 8 | udala
# Processing Record 40 of Set 8 | marsh harbour
# Processing Record 41 of Set 8 | lata
# Processing Record 42 of Set 8 | mbekenyera
# Processing Record 43 of Set 8 | bougouni
# Processing Record 44 of Set 8 | halmstad
# Processing Record 45 of Set 8 | ushtobe
# Processing Record 46 of Set 8 | kaitangata
# Processing Record 47 of Set 8 | nalundan
# Processing Record 48 of Set 8 | ketchikan
# Processing Record 49 of Set 8 | oia
# Processing Record 50 of Set 8 | kusa
# Processing Record 1 of Set 9 | amapa
# Processing Record 2 of Set 9 | hadgaon
# Processing Record 3 of Set 9 | lagoa
# Processing Record 4 of Set 9 | yerbogachen
# Processing Record 5 of Set 9 | puerto baquerizo moreno
# Processing Record 6 of Set 9 | carnarvon
# Processing Record 7 of Set 9 | buxtehude
# Processing Record 8 of Set 9 | emerald
# Processing Record 9 of Set 9 | manggar
# Processing Record 10 of Set 9 | corn island
# Processing Record 11 of Set 9 | severo-kurilsk
# Processing Record 12 of Set 9 | ostrovnoy
# Processing Record 13 of Set 9 | torbat-e jam
# Processing Record 14 of Set 9 | damghan
# Processing Record 15 of Set 9 | vila velha
# Processing Record 16 of Set 9 | kabwe
# Processing Record 17 of Set 9 | wazzan
# City not found. Skipping...
# Processing Record 18 of Set 9 | usinsk
# Processing Record 19 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 9 | ahipara
# Processing Record 21 of Set 9 | perth
# Processing Record 22 of Set 9 | najran
# Processing Record 23 of Set 9 | rosario do sul
# Processing Record 24 of Set 9 | aksu
# Processing Record 25 of Set 9 | snezhnogorsk
# Processing Record 26 of Set 9 | mahon
# Processing Record 27 of Set 9 | havre-saint-pierre
# Processing Record 28 of Set 9 | hasaki
# Processing Record 29 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 9 | obo
# Processing Record 31 of Set 9 | las margaritas
# Processing Record 32 of Set 9 | sao francisco do sul
# Processing Record 33 of Set 9 | arys
# Processing Record 34 of Set 9 | syracuse
# Processing Record 35 of Set 9 | moron
# Processing Record 36 of Set 9 | mecca
# Processing Record 37 of Set 9 | pilar
# Processing Record 38 of Set 9 | jati
# Processing Record 39 of Set 9 | lianzhou
# Processing Record 40 of Set 9 | quatre cocos
# Processing Record 41 of Set 9 | phangnga
# Processing Record 42 of Set 9 | maymyo
# Processing Record 43 of Set 9 | cotonou
# Processing Record 44 of Set 9 | guanay
# Processing Record 45 of Set 9 | smoky lake
# Processing Record 46 of Set 9 | tadine
# Processing Record 47 of Set 9 | sibay
# Processing Record 48 of Set 9 | san patricio
# Processing Record 49 of Set 9 | inirida
# Processing Record 50 of Set 9 | matagami
# Processing Record 1 of Set 10 | kruisfontein
# Processing Record 2 of Set 10 | kedgwick
# Processing Record 3 of Set 10 | san lucas
# Processing Record 4 of Set 10 | carutapera
# Processing Record 5 of Set 10 | jackson
# Processing Record 6 of Set 10 | manaus
# Processing Record 7 of Set 10 | nhulunbuy
# Processing Record 8 of Set 10 | oktyabrskoye
# Processing Record 9 of Set 10 | beloha
# Processing Record 10 of Set 10 | nikel
# Processing Record 11 of Set 10 | imeni poliny osipenko
# Processing Record 12 of Set 10 | tomatlan
# Processing Record 13 of Set 10 | port-gentil
# Processing Record 14 of Set 10 | albion
# Processing Record 15 of Set 10 | khandyga
# Processing Record 16 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 17 of Set 10 | skovorodino
# Processing Record 18 of Set 10 | kupang
# Processing Record 19 of Set 10 | honiara
# Processing Record 20 of Set 10 | kapoeta
# Processing Record 21 of Set 10 | velyka bahachka
# Processing Record 22 of Set 10 | leningradskiy
# Processing Record 23 of Set 10 | amga
# Processing Record 24 of Set 10 | artyom
# Processing Record 25 of Set 10 | pestovo
# Processing Record 26 of Set 10 | port lincoln
# Processing Record 27 of Set 10 | dindigul
# Processing Record 28 of Set 10 | llallagua
# Processing Record 29 of Set 10 | ranong
# Processing Record 30 of Set 10 | svetlogorsk
# Processing Record 31 of Set 10 | alcudia
# Processing Record 32 of Set 10 | kirakira
# Processing Record 33 of Set 10 | santa rosa
# Processing Record 34 of Set 10 | san jose
# Processing Record 35 of Set 10 | siguiri
# Processing Record 36 of Set 10 | emilio carranza
# Processing Record 37 of Set 10 | vila do maio
# Processing Record 38 of Set 10 | vermilion
# Processing Record 39 of Set 10 | paka
# Processing Record 40 of Set 10 | bonavista
# Processing Record 41 of Set 10 | tarakan
# Processing Record 42 of Set 10 | shirvan
# Processing Record 43 of Set 10 | stodolishche
# Processing Record 44 of Set 10 | cayenne
# Processing Record 45 of Set 10 | meulaboh
# Processing Record 46 of Set 10 | miles city
# Processing Record 47 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 48 of Set 10 | te anau
# Processing Record 49 of Set 10 | kaminokawa
# Processing Record 50 of Set 10 | ust-ilimsk
# Processing Record 1 of Set 11 | lamu
# Processing Record 2 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 3 of Set 11 | aklavik
# Processing Record 4 of Set 11 | san lazaro
# Processing Record 5 of Set 11 | berlevag
# Processing Record 6 of Set 11 | zhanaozen
# Processing Record 7 of Set 11 | zhezkazgan
# Processing Record 8 of Set 11 | todos santos
# Processing Record 9 of Set 11 | kimbe
# Processing Record 10 of Set 11 | manado
# Processing Record 11 of Set 11 | key largo
# Processing Record 12 of Set 11 | lipin bor
# Processing Record 13 of Set 11 | codrington
# Processing Record 14 of Set 11 | coahuayana
# Processing Record 15 of Set 11 | dudinka
# Processing Record 16 of Set 11 | kieta
# Processing Record 17 of Set 11 | kailua
# Processing Record 18 of Set 11 | atambua
# Processing Record 19 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 20 of Set 11 | petropavlovka
# Processing Record 21 of Set 11 | akcakoca
# Processing Record 22 of Set 11 | kavaratti
# Processing Record 23 of Set 11 | kuusamo
# Processing Record 24 of Set 11 | jumla
# Processing Record 25 of Set 11 | bubaque
# Processing Record 26 of Set 11 | launceston
# Processing Record 27 of Set 11 | lesosibirsk
# Processing Record 28 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 11 | dongsheng
# Processing Record 30 of Set 11 | dingle
# Processing Record 31 of Set 11 | fort frances
# Processing Record 32 of Set 11 | samarai
# Processing Record 33 of Set 11 | sakakah
# Processing Record 34 of Set 11 | riverton
# Processing Record 35 of Set 11 | arauca
# Processing Record 36 of Set 11 | porto santo
# Processing Record 37 of Set 11 | santa maria del oro
# Processing Record 38 of Set 11 | nemuro
# Processing Record 39 of Set 11 | oussouye
# Processing Record 40 of Set 11 | maputo
# Processing Record 41 of Set 11 | rio grande
# Processing Record 42 of Set 11 | marrakesh
# Processing Record 43 of Set 11 | machacamarca
# Processing Record 44 of Set 11 | esmeraldas
# Processing Record 45 of Set 11 | qarqin
# Processing Record 46 of Set 11 | urucara
# Processing Record 47 of Set 11 | black river
# Processing Record 48 of Set 11 | cumpas
# Processing Record 49 of Set 11 | silae
# Processing Record 50 of Set 11 | krasnogvardeyets
# Processing Record 1 of Set 12 | wilmington
# Processing Record 2 of Set 12 | dawlatabad
# Processing Record 3 of Set 12 | thinadhoo
# Processing Record 4 of Set 12 | hamcearca
# Processing Record 5 of Set 12 | nouadhibou
# Processing Record 6 of Set 12 | zyryanovsk
# Processing Record 7 of Set 12 | taiyuan
# Processing Record 8 of Set 12 | bushenyi
# Processing Record 9 of Set 12 | lasa
# Processing Record 10 of Set 12 | kloulklubed
# Processing Record 11 of Set 12 | minden
# Processing Record 12 of Set 12 | tuatapere
# Processing Record 13 of Set 12 | manokwari
# Processing Record 14 of Set 12 | kudahuvadhoo
# Processing Record 15 of Set 12 | ixtapa
# Processing Record 16 of Set 12 | jinchang
# Processing Record 17 of Set 12 | peterhead
# Processing Record 18 of Set 12 | gorontalo
# Processing Record 19 of Set 12 | torbay
# Processing Record 20 of Set 12 | bacolod
# Processing Record 21 of Set 12 | cilegon
# Processing Record 22 of Set 12 | kualakapuas
# Processing Record 23 of Set 12 | gerede
# Processing Record 24 of Set 12 | agropoli
# Processing Record 25 of Set 12 | kinshasa
# Processing Record 26 of Set 12 | xuddur
# Processing Record 27 of Set 12 | bo phloi
# Processing Record 28 of Set 12 | springbok
# Processing Record 29 of Set 12 | bilma
# Processing Record 30 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 12 | saint-die
# City not found. Skipping...
# Processing Record 32 of Set 12 | mayumba
# Processing Record 33 of Set 12 | naze
# Processing Record 34 of Set 12 | markdale
# Processing Record 35 of Set 12 | okakarara
# Processing Record 36 of Set 12 | ceres
# Processing Record 37 of Set 12 | cabo san lucas
# Processing Record 38 of Set 12 | pitimbu
# Processing Record 39 of Set 12 | taguatinga
# Processing Record 40 of Set 12 | comodoro rivadavia
# Processing Record 41 of Set 12 | palembang
# Processing Record 42 of Set 12 | yaypan
# Processing Record 43 of Set 12 | reconquista
# Processing Record 44 of Set 12 | mocuba
# Processing Record 45 of Set 12 | plymouth
# Processing Record 46 of Set 12 | aras
# Processing Record 47 of Set 12 | ahuimanu
# Processing Record 48 of Set 12 | kindu
# Processing Record 49 of Set 12 | esterhazy
# Processing Record 50 of Set 12 | oum hadjer
# Processing Record 1 of Set 13 | byron bay
# Processing Record 2 of Set 13 | rio gallegos
# Processing Record 3 of Set 13 | yar-sale
# Processing Record 4 of Set 13 | shimoda
# Processing Record 5 of Set 13 | seydi
# Processing Record 6 of Set 13 | san quintin
# Processing Record 7 of Set 13 | arnia
# Processing Record 8 of Set 13 | murayama
# Processing Record 9 of Set 13 | canto do buriti
# Processing Record 10 of Set 13 | logansport
# Processing Record 11 of Set 13 | puerto escondido
# Processing Record 12 of Set 13 | kushiro
# Processing Record 13 of Set 13 | ulagan
# Processing Record 14 of Set 13 | greensburg
# Processing Record 15 of Set 13 | maiduguri
# Processing Record 16 of Set 13 | tabou
# Processing Record 17 of Set 13 | simiti
# Processing Record 18 of Set 13 | manoel urbano
# Processing Record 19 of Set 13 | novobirilyussy
# Processing Record 20 of Set 13 | nivala
# Processing Record 21 of Set 13 | ibra
# Processing Record 22 of Set 13 | puerto carreno
# Processing Record 23 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 13 | makinsk
# Processing Record 25 of Set 13 | kalmunai
# Processing Record 26 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 13 | qui nhon
# Processing Record 28 of Set 13 | vardo
# Processing Record 29 of Set 13 | ziyang
# Processing Record 30 of Set 13 | nizhneudinsk
# Processing Record 31 of Set 13 | taoudenni
# Processing Record 32 of Set 13 | foumban
# Processing Record 33 of Set 13 | tonekabon
# Processing Record 34 of Set 13 | petrykivka
# Processing Record 35 of Set 13 | pouso alegre
# Processing Record 36 of Set 13 | luis correia
# Processing Record 37 of Set 13 | cap-aux-meules
# Processing Record 38 of Set 13 | west wendover
# Processing Record 39 of Set 13 | dire dawa
# Processing Record 40 of Set 13 | cremlingen
# Processing Record 41 of Set 13 | contrecoeur
# Processing Record 42 of Set 13 | vanderhoof
# Processing Record 43 of Set 13 | dhandhuka
# Processing Record 44 of Set 13 | westport
# Processing Record 45 of Set 13 | ayer itam
# City not found. Skipping...
# Processing Record 46 of Set 13 | puteyets
# Processing Record 47 of Set 13 | neiafu
# Processing Record 48 of Set 13 | makakilo city
# Processing Record 49 of Set 13 | karratha
# Processing Record 50 of Set 13 | hangu
# Processing Record 1 of Set 14 | hovd
# Processing Record 2 of Set 14 | barroquinha
# Processing Record 3 of Set 14 | evensk
# Processing Record 4 of Set 14 | medicine hat
# Processing Record 5 of Set 14 | tommot
# Processing Record 6 of Set 14 | ekhabi
# Processing Record 7 of Set 14 | ouro branco
# Processing Record 8 of Set 14 | preobrazheniye
# Processing Record 9 of Set 14 | trincomalee
# Processing Record 10 of Set 14 | moerai
# Processing Record 11 of Set 14 | popondetta
# Processing Record 12 of Set 14 | yara
# Processing Record 13 of Set 14 | aquiraz
# Processing Record 14 of Set 14 | tres picos
# Processing Record 15 of Set 14 | the valley
# Processing Record 16 of Set 14 | gardiner
# Processing Record 17 of Set 14 | kerema
# Processing Record 18 of Set 14 | valparaiso
# Processing Record 19 of Set 14 | juneau
# Processing Record 20 of Set 14 | mango
# Processing Record 21 of Set 14 | flinders
# Processing Record 22 of Set 14 | mareeba
# Processing Record 23 of Set 14 | fuxin
# Processing Record 24 of Set 14 | vanavara
# Processing Record 25 of Set 14 | luwuk
# Processing Record 26 of Set 14 | kawalu
# Processing Record 27 of Set 14 | siniscola
# Processing Record 28 of Set 14 | emba
# Processing Record 29 of Set 14 | kamenka
# Processing Record 30 of Set 14 | sungaipenuh
# Processing Record 31 of Set 14 | buenos aires
# Processing Record 32 of Set 14 | mayor pablo lagerenza
# Processing Record 33 of Set 14 | tyup
# Processing Record 34 of Set 14 | gat
# Processing Record 35 of Set 14 | assiniboia
# Processing Record 36 of Set 14 | morro bay
# Processing Record 37 of Set 14 | akyab
# Processing Record 38 of Set 14 | abu zabad
# Processing Record 39 of Set 14 | iwanai
# Processing Record 40 of Set 14 | groningen
# Processing Record 41 of Set 14 | pohrebyshche
# Processing Record 42 of Set 14 | lembeni
# Processing Record 43 of Set 14 | bardiyah
# Processing Record 44 of Set 14 | chingola
# Processing Record 45 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 14 | murud
# Processing Record 47 of Set 14 | gigmoto
# Processing Record 48 of Set 14 | charters towers
# Processing Record 49 of Set 14 | nueve de julio
# Processing Record 50 of Set 14 | necochea
# Processing Record 1 of Set 15 | los llanos de aridane
# Processing Record 2 of Set 15 | feijo
# Processing Record 3 of Set 15 | cap malheureux
# Processing Record 4 of Set 15 | mbini
# Processing Record 5 of Set 15 | ylivieska
# Processing Record 6 of Set 15 | khorixas
# Processing Record 7 of Set 15 | leshukonskoye
# Processing Record 8 of Set 15 | zheleznodorozhnyy
# Processing Record 9 of Set 15 | ames
# Processing Record 10 of Set 15 | camabatela
# Processing Record 11 of Set 15 | mittagong
# Processing Record 12 of Set 15 | pochutla
# Processing Record 13 of Set 15 | zyryanka
# Processing Record 14 of Set 15 | sampit
# Processing Record 15 of Set 15 | terre haute
# Processing Record 16 of Set 15 | arman
# Processing Record 17 of Set 15 | kaspiyskiy
# Processing Record 18 of Set 15 | kitui
# Processing Record 19 of Set 15 | marsa matruh
# Processing Record 20 of Set 15 | kyzyl-suu
# Processing Record 21 of Set 15 | vestmanna
# Processing Record 22 of Set 15 | la peca
# Processing Record 23 of Set 15 | elbistan
# Processing Record 24 of Set 15 | hudson bay
# Processing Record 25 of Set 15 | luanda
# Processing Record 26 of Set 15 | morinville
# Processing Record 27 of Set 15 | mosquera
# Processing Record 28 of Set 15 | smithers
# Processing Record 29 of Set 15 | caucaia
# Processing Record 30 of Set 15 | hayato
# City not found. Skipping...
# Processing Record 31 of Set 15 | tarpon springs
# Processing Record 32 of Set 15 | malaya serdoba
# Processing Record 33 of Set 15 | solnechnyy
# Processing Record 34 of Set 15 | baghmara
# Processing Record 35 of Set 15 | caraz
# Processing Record 36 of Set 15 | manhumirim
# Processing Record 37 of Set 15 | lundazi
# Processing Record 38 of Set 15 | morondava
# Processing Record 39 of Set 15 | macesu de sus
# Processing Record 40 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 41 of Set 15 | rolla
# Processing Record 42 of Set 15 | lorengau
# Processing Record 43 of Set 15 | lazaro cardenas
# Processing Record 44 of Set 15 | ilebo
# Processing Record 45 of Set 15 | coruripe
# Processing Record 46 of Set 15 | wanning
# Processing Record 47 of Set 15 | turbat
# Processing Record 48 of Set 15 | lefka
# Processing Record 49 of Set 15 | fayaoue
# Processing Record 50 of Set 15 | podlesnyy
# Processing Record 1 of Set 16 | passo de camaragibe
# Processing Record 2 of Set 16 | lisala
# Processing Record 3 of Set 16 | plouzane
# Processing Record 4 of Set 16 | ende
# Processing Record 5 of Set 16 | kiomboi
# Processing Record 6 of Set 16 | mende
# Processing Record 7 of Set 16 | cimarron hills
# Processing Record 8 of Set 16 | kununurra
# Processing Record 9 of Set 16 | imbituba
# Processing Record 10 of Set 16 | winslow
# Processing Record 11 of Set 16 | ambilobe
# Processing Record 12 of Set 16 | vernon
# Processing Record 13 of Set 16 | borovskoy
# Processing Record 14 of Set 16 | sisimiut
# Processing Record 15 of Set 16 | jining
# Processing Record 16 of Set 16 | hailey
# Processing Record 17 of Set 16 | hirara
# Processing Record 18 of Set 16 | zapolyarnyy
# Processing Record 19 of Set 16 | dunedin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 714

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.15  -70.92     48.20        61          75
# 1          Vaini      TO -21.20 -175.20     75.20        73          75
# 2          Bluff      NZ -46.60  168.33     60.01        56          95
# 3       Takoradi      GH   4.88   -1.76     76.69        92          65
# 4        Sorland      NO  67.67   12.69     37.04        78          92
# 5      Busselton      AU -33.65  115.33     66.00        55          15
# 6         Manono      CD  -7.30   27.42     69.37        91         100
# 7       Bengkulu      ID  -3.80  102.27     81.01        72         100
# 8            Sur      OM  22.57   59.53     78.40        59           2
# 9  Alice Springs      AU -23.70  133.88     98.60        20          40
#
#    Wind Speed Current description
# 0        5.82       broken clouds
# 1        9.17       broken clouds
# 2        7.00     overcast clouds
# 3        7.05       broken clouds
# 4       11.54     overcast clouds
# 5        1.99          few clouds
# 6        1.68     overcast clouds
# 7        5.86     overcast clouds
# 8        8.81           clear sky
# 9       19.46                dust

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
