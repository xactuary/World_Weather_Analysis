# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=df7e1a45d4925410a8ba4c0d3e685ca0

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.  Record numbers 1-50 and the set counter - how many sets of 50
record_count = 1
set_count = 1

# Loop through all the cities in the list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes. 
    #If the remainder of the index divided by 50 ==0 and if the index is greater than or equal to 50
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
      
    # Create endpoint URL with each city.  replace blanks with "+" which finds the weather for the city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_desc = city_weather["weather"][0]["description"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | ankang
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | ketchikan
# Processing Record 6 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | senmonorom
# City not found. Skipping...
# Processing Record 9 of Set 1 | killybegs
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | los llanos de aridane
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | taoudenni
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | great yarmouth
# Processing Record 20 of Set 1 | helong
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | lebu
# Processing Record 24 of Set 1 | prosvet
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | tommot
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 1 | lompoc
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | clyde river
# Processing Record 33 of Set 1 | coquimbo
# Processing Record 34 of Set 1 | gamba
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | upernavik
# Processing Record 37 of Set 1 | lintangan
# Processing Record 38 of Set 1 | airai
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | skibbereen
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | guerrero negro
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | tazovskiy
# Processing Record 48 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 1 | miyako
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 2 | ust-kan
# Processing Record 3 of Set 2 | quatre cocos
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | coos bay
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | agadez
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | manzhouli
# Processing Record 11 of Set 2 | dokri
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | fortuna
# Processing Record 14 of Set 2 | gorontalo
# Processing Record 15 of Set 2 | avarua
# Processing Record 16 of Set 2 | saint-augustin
# Processing Record 17 of Set 2 | pisco
# Processing Record 18 of Set 2 | kavaratti
# Processing Record 19 of Set 2 | simao
# Processing Record 20 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 2 | vostok
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | chicla
# Processing Record 25 of Set 2 | kristiansund
# Processing Record 26 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 27 of Set 2 | pangnirtung
# Processing Record 28 of Set 2 | liberal
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | brae
# Processing Record 31 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 32 of Set 2 | saint anthony
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | saint-joseph
# Processing Record 35 of Set 2 | awbari
# Processing Record 36 of Set 2 | ancud
# Processing Record 37 of Set 2 | boo
# Processing Record 38 of Set 2 | ranong
# Processing Record 39 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 2 | aklavik
# Processing Record 41 of Set 2 | high prairie
# Processing Record 42 of Set 2 | ures
# Processing Record 43 of Set 2 | abu dhabi
# Processing Record 44 of Set 2 | la ronge
# Processing Record 45 of Set 2 | broken hill
# Processing Record 46 of Set 2 | bengkulu
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 2 | okha
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 2 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 3 | provideniya
# Processing Record 5 of Set 3 | yakeshi
# Processing Record 6 of Set 3 | pindiga
# Processing Record 7 of Set 3 | mount gambier
# Processing Record 8 of Set 3 | pyshma
# Processing Record 9 of Set 3 | rikitea
# Processing Record 10 of Set 3 | hovd
# Processing Record 11 of Set 3 | picota
# Processing Record 12 of Set 3 | meulaboh
# Processing Record 13 of Set 3 | la rioja
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | port elizabeth
# Processing Record 16 of Set 3 | caravelas
# Processing Record 17 of Set 3 | mnogovershinnyy
# Processing Record 18 of Set 3 | itoman
# Processing Record 19 of Set 3 | kahului
# Processing Record 20 of Set 3 | gazimurskiy zavod
# Processing Record 21 of Set 3 | pringsewu
# Processing Record 22 of Set 3 | canon city
# Processing Record 23 of Set 3 | rio gallegos
# Processing Record 24 of Set 3 | zeya
# Processing Record 25 of Set 3 | kununurra
# Processing Record 26 of Set 3 | marsh harbour
# Processing Record 27 of Set 3 | atbasar
# Processing Record 28 of Set 3 | vaini
# Processing Record 29 of Set 3 | lasa
# Processing Record 30 of Set 3 | codrington
# Processing Record 31 of Set 3 | nioro
# Processing Record 32 of Set 3 | agadir
# Processing Record 33 of Set 3 | beidao
# Processing Record 34 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | coahuayana
# Processing Record 37 of Set 3 | necochea
# Processing Record 38 of Set 3 | nemuro
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | kavieng
# Processing Record 41 of Set 3 | kirakira
# Processing Record 42 of Set 3 | grand gaube
# Processing Record 43 of Set 3 | skjervoy
# Processing Record 44 of Set 3 | belaya gora
# Processing Record 45 of Set 3 | gubkin
# Processing Record 46 of Set 3 | mastic beach
# Processing Record 47 of Set 3 | pinega
# Processing Record 48 of Set 3 | batken
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | sal rei
# Processing Record 1 of Set 4 | kolokani
# Processing Record 2 of Set 4 | pevek
# Processing Record 3 of Set 4 | iznik
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 4 | wajima
# Processing Record 7 of Set 4 | eureka
# Processing Record 8 of Set 4 | hornepayne
# Processing Record 9 of Set 4 | farmington
# Processing Record 10 of Set 4 | gimli
# Processing Record 11 of Set 4 | cartagena
# Processing Record 12 of Set 4 | salalah
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | udimskiy
# Processing Record 15 of Set 4 | acapulco
# Processing Record 16 of Set 4 | hofn
# Processing Record 17 of Set 4 | khatanga
# Processing Record 18 of Set 4 | klaksvik
# Processing Record 19 of Set 4 | auchterarder
# Processing Record 20 of Set 4 | monrovia
# Processing Record 21 of Set 4 | tuatapere
# Processing Record 22 of Set 4 | elbrus
# Processing Record 23 of Set 4 | nikolskoye
# Processing Record 24 of Set 4 | victoria
# Processing Record 25 of Set 4 | zwedru
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | dunedin
# Processing Record 28 of Set 4 | omsukchan
# Processing Record 29 of Set 4 | mizpe ramon
# City not found. Skipping...
# Processing Record 30 of Set 4 | buala
# Processing Record 31 of Set 4 | ugoofaaru
# Processing Record 32 of Set 4 | mehamn
# Processing Record 33 of Set 4 | ilulissat
# Processing Record 34 of Set 4 | dingle
# Processing Record 35 of Set 4 | bathsheba
# Processing Record 36 of Set 4 | vryheid
# Processing Record 37 of Set 4 | filadelfia
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | orange
# Processing Record 40 of Set 4 | sulzbach-rosenberg
# Processing Record 41 of Set 4 | chumikan
# Processing Record 42 of Set 4 | flinders
# Processing Record 43 of Set 4 | haines junction
# Processing Record 44 of Set 4 | pangody
# Processing Record 45 of Set 4 | olot
# Processing Record 46 of Set 4 | magadan
# Processing Record 47 of Set 4 | santiago de cao
# Processing Record 48 of Set 4 | banda aceh
# Processing Record 49 of Set 4 | alcudia
# Processing Record 50 of Set 4 | santa maria
# Processing Record 1 of Set 5 | valdosta
# Processing Record 2 of Set 5 | luderitz
# Processing Record 3 of Set 5 | bonfim
# Processing Record 4 of Set 5 | berdigestyakh
# Processing Record 5 of Set 5 | san rafael
# Processing Record 6 of Set 5 | kawalu
# Processing Record 7 of Set 5 | isoka
# Processing Record 8 of Set 5 | port blair
# Processing Record 9 of Set 5 | new norfolk
# Processing Record 10 of Set 5 | alofi
# Processing Record 11 of Set 5 | kaitangata
# Processing Record 12 of Set 5 | vardo
# Processing Record 13 of Set 5 | watsa
# Processing Record 14 of Set 5 | westport
# Processing Record 15 of Set 5 | matagami
# Processing Record 16 of Set 5 | krasnoselkup
# Processing Record 17 of Set 5 | loiza
# Processing Record 18 of Set 5 | ibra
# Processing Record 19 of Set 5 | dali
# Processing Record 20 of Set 5 | hidalgotitlan
# Processing Record 21 of Set 5 | mayahi
# Processing Record 22 of Set 5 | pizhma
# Processing Record 23 of Set 5 | inirida
# Processing Record 24 of Set 5 | havre-saint-pierre
# Processing Record 25 of Set 5 | rio de janeiro
# Processing Record 26 of Set 5 | hamilton
# Processing Record 27 of Set 5 | xining
# Processing Record 28 of Set 5 | pishin
# Processing Record 29 of Set 5 | kasulu
# Processing Record 30 of Set 5 | sur
# Processing Record 31 of Set 5 | edgemere
# Processing Record 32 of Set 5 | nabire
# Processing Record 33 of Set 5 | sola
# Processing Record 34 of Set 5 | tocopilla
# Processing Record 35 of Set 5 | kerteh
# City not found. Skipping...
# Processing Record 36 of Set 5 | tecoanapa
# Processing Record 37 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 5 | katsuura
# Processing Record 39 of Set 5 | bambous virieux
# Processing Record 40 of Set 5 | del rio
# Processing Record 41 of Set 5 | bonthe
# Processing Record 42 of Set 5 | kedrovyy
# Processing Record 43 of Set 5 | bintulu
# Processing Record 44 of Set 5 | chuy
# Processing Record 45 of Set 5 | manavalakurichi
# Processing Record 46 of Set 5 | port augusta
# Processing Record 47 of Set 5 | esperance
# Processing Record 48 of Set 5 | monster
# Processing Record 49 of Set 5 | slavyanka
# Processing Record 50 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 6 | belmonte
# Processing Record 2 of Set 6 | palauig
# Processing Record 3 of Set 6 | dikson
# Processing Record 4 of Set 6 | zatyshshya
# Processing Record 5 of Set 6 | seoul
# Processing Record 6 of Set 6 | hobyo
# Processing Record 7 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 6 | cabedelo
# Processing Record 9 of Set 6 | norsup
# Processing Record 10 of Set 6 | ahipara
# Processing Record 11 of Set 6 | gondanglegi
# Processing Record 12 of Set 6 | bandarbeyla
# Processing Record 13 of Set 6 | borna
# Processing Record 14 of Set 6 | aswan
# Processing Record 15 of Set 6 | kindu
# Processing Record 16 of Set 6 | cherskiy
# Processing Record 17 of Set 6 | khormuj
# City not found. Skipping...
# Processing Record 18 of Set 6 | uwayl
# City not found. Skipping...
# Processing Record 19 of Set 6 | san quintin
# Processing Record 20 of Set 6 | salta
# Processing Record 21 of Set 6 | torbat-e jam
# Processing Record 22 of Set 6 | arrecife
# Processing Record 23 of Set 6 | maues
# Processing Record 24 of Set 6 | sembe
# Processing Record 25 of Set 6 | havelock
# Processing Record 26 of Set 6 | tiksi
# Processing Record 27 of Set 6 | kodiak
# Processing Record 28 of Set 6 | alice springs
# Processing Record 29 of Set 6 | vidalia
# Processing Record 30 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 6 | mizan teferi
# Processing Record 32 of Set 6 | port lincoln
# Processing Record 33 of Set 6 | berlevag
# Processing Record 34 of Set 6 | rudsar
# Processing Record 35 of Set 6 | lazaro cardenas
# Processing Record 36 of Set 6 | chaman
# Processing Record 37 of Set 6 | sitka
# Processing Record 38 of Set 6 | namibe
# Processing Record 39 of Set 6 | mayo
# Processing Record 40 of Set 6 | tortoli
# Processing Record 41 of Set 6 | xinyu
# Processing Record 42 of Set 6 | hambantota
# Processing Record 43 of Set 6 | kibala
# Processing Record 44 of Set 6 | norman wells
# Processing Record 45 of Set 6 | ostrovnoy
# Processing Record 46 of Set 6 | beira
# Processing Record 47 of Set 6 | odweyne
# Processing Record 48 of Set 6 | hegang
# Processing Record 49 of Set 6 | southbridge
# Processing Record 50 of Set 6 | cikampek
# Processing Record 1 of Set 7 | andenes
# Processing Record 2 of Set 7 | yar-sale
# Processing Record 3 of Set 7 | hithadhoo
# Processing Record 4 of Set 7 | cantagallo
# Processing Record 5 of Set 7 | evensk
# Processing Record 6 of Set 7 | mezen
# Processing Record 7 of Set 7 | daura
# Processing Record 8 of Set 7 | cockburn town
# Processing Record 9 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 7 | klyuchi
# Processing Record 11 of Set 7 | constitucion
# Processing Record 12 of Set 7 | hammerfest
# Processing Record 13 of Set 7 | sangar
# Processing Record 14 of Set 7 | zhigansk
# Processing Record 15 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 7 | cabo san lucas
# Processing Record 17 of Set 7 | amahai
# Processing Record 18 of Set 7 | geri
# Processing Record 19 of Set 7 | yatou
# Processing Record 20 of Set 7 | fildu de jos
# Processing Record 21 of Set 7 | vung tau
# Processing Record 22 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 7 | ulaangom
# Processing Record 25 of Set 7 | sarkand
# Processing Record 26 of Set 7 | osypenko
# Processing Record 27 of Set 7 | kosonsoy
# Processing Record 28 of Set 7 | narsaq
# Processing Record 29 of Set 7 | sabzevar
# Processing Record 30 of Set 7 | harper
# Processing Record 31 of Set 7 | loreto
# Processing Record 32 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 7 | saint-pierre
# Processing Record 34 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 7 | youkounkoun
# Processing Record 36 of Set 7 | saint-paul
# Processing Record 37 of Set 7 | sioux lookout
# Processing Record 38 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 7 | hervey bay
# Processing Record 40 of Set 7 | codajas
# Processing Record 41 of Set 7 | batsfjord
# Processing Record 42 of Set 7 | hualmay
# Processing Record 43 of Set 7 | cap malheureux
# Processing Record 44 of Set 7 | sri aman
# Processing Record 45 of Set 7 | sibu
# Processing Record 46 of Set 7 | arua
# Processing Record 47 of Set 7 | thaba-tseka
# Processing Record 48 of Set 7 | comodoro rivadavia
# Processing Record 49 of Set 7 | seydi
# Processing Record 50 of Set 7 | siva
# Processing Record 1 of Set 8 | tasiilaq
# Processing Record 2 of Set 8 | ko samui
# Processing Record 3 of Set 8 | coihaique
# Processing Record 4 of Set 8 | talnakh
# Processing Record 5 of Set 8 | baruun-urt
# Processing Record 6 of Set 8 | syracuse
# Processing Record 7 of Set 8 | praia
# Processing Record 8 of Set 8 | garissa
# Processing Record 9 of Set 8 | porirua
# Processing Record 10 of Set 8 | san javier
# Processing Record 11 of Set 8 | zyryanka
# Processing Record 12 of Set 8 | caxito
# Processing Record 13 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 8 | rosita
# Processing Record 15 of Set 8 | itupiranga
# Processing Record 16 of Set 8 | banjar
# Processing Record 17 of Set 8 | berwick
# Processing Record 18 of Set 8 | viedma
# Processing Record 19 of Set 8 | storsteinnes
# Processing Record 20 of Set 8 | kapuskasing
# Processing Record 21 of Set 8 | rawson
# Processing Record 22 of Set 8 | kruisfontein
# Processing Record 23 of Set 8 | ziarat
# Processing Record 24 of Set 8 | iqaluit
# Processing Record 25 of Set 8 | baft
# Processing Record 26 of Set 8 | anadyr
# Processing Record 27 of Set 8 | giyon
# Processing Record 28 of Set 8 | arakhnaion
# City not found. Skipping...
# Processing Record 29 of Set 8 | asau
# Processing Record 30 of Set 8 | xiongshi
# City not found. Skipping...
# Processing Record 31 of Set 8 | northampton
# Processing Record 32 of Set 8 | morehead
# Processing Record 33 of Set 8 | srednekolymsk
# Processing Record 34 of Set 8 | kalianget
# Processing Record 35 of Set 8 | vila franca do campo
# Processing Record 36 of Set 8 | el carmen
# Processing Record 37 of Set 8 | dalbandin
# Processing Record 38 of Set 8 | lerdo
# Processing Record 39 of Set 8 | eluru
# Processing Record 40 of Set 8 | novoagansk
# Processing Record 41 of Set 8 | lorengau
# Processing Record 42 of Set 8 | bethanien
# Processing Record 43 of Set 8 | camocim
# Processing Record 44 of Set 8 | subiaco
# Processing Record 45 of Set 8 | severnyy
# Processing Record 46 of Set 8 | tamale
# Processing Record 47 of Set 8 | nueva loja
# Processing Record 48 of Set 8 | tura
# Processing Record 49 of Set 8 | soe
# Processing Record 50 of Set 8 | burica
# City not found. Skipping...
# Processing Record 1 of Set 9 | ulagan
# Processing Record 2 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 9 | thunder bay
# Processing Record 4 of Set 9 | ormara
# Processing Record 5 of Set 9 | anloga
# Processing Record 6 of Set 9 | umm lajj
# Processing Record 7 of Set 9 | kondinskoye
# Processing Record 8 of Set 9 | banyo
# Processing Record 9 of Set 9 | tarbagatay
# Processing Record 10 of Set 9 | fraga
# Processing Record 11 of Set 9 | beringovskiy
# Processing Record 12 of Set 9 | conversano
# Processing Record 13 of Set 9 | arlit
# Processing Record 14 of Set 9 | porto torres
# Processing Record 15 of Set 9 | amuntai
# Processing Record 16 of Set 9 | meiganga
# Processing Record 17 of Set 9 | moron
# Processing Record 18 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 9 | grenaa
# Processing Record 20 of Set 9 | esmeraldas
# Processing Record 21 of Set 9 | seddon
# Processing Record 22 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 9 | fare
# Processing Record 24 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 9 | college
# Processing Record 26 of Set 9 | totness
# Processing Record 27 of Set 9 | aykhal
# Processing Record 28 of Set 9 | lianran
# Processing Record 29 of Set 9 | hami
# Processing Record 30 of Set 9 | rocha
# Processing Record 31 of Set 9 | burgersdorp
# Processing Record 32 of Set 9 | omboue
# Processing Record 33 of Set 9 | faya
# Processing Record 34 of Set 9 | ubinskoye
# Processing Record 35 of Set 9 | adre
# Processing Record 36 of Set 9 | fonte boa
# Processing Record 37 of Set 9 | katherine
# Processing Record 38 of Set 9 | durango
# Processing Record 39 of Set 9 | te anau
# Processing Record 40 of Set 9 | hasaki
# Processing Record 41 of Set 9 | namatanai
# Processing Record 42 of Set 9 | mana
# Processing Record 43 of Set 9 | constantine
# Processing Record 44 of Set 9 | deputatskiy
# Processing Record 45 of Set 9 | ugljevik
# Processing Record 46 of Set 9 | mahenge
# Processing Record 47 of Set 9 | merauke
# Processing Record 48 of Set 9 | escuinapa
# Processing Record 49 of Set 9 | jalu
# Processing Record 50 of Set 9 | tumaco
# Processing Record 1 of Set 10 | buin
# Processing Record 2 of Set 10 | moorhead
# Processing Record 3 of Set 10 | sechura
# Processing Record 4 of Set 10 | tigzirt
# Processing Record 5 of Set 10 | manoel urbano
# Processing Record 6 of Set 10 | san jose
# Processing Record 7 of Set 10 | marawi
# Processing Record 8 of Set 10 | murray bridge
# Processing Record 9 of Set 10 | wadi musa
# Processing Record 10 of Set 10 | puerto asis
# Processing Record 11 of Set 10 | port hardy
# Processing Record 12 of Set 10 | itamarandiba
# Processing Record 13 of Set 10 | thanh hoa
# Processing Record 14 of Set 10 | mazagao
# Processing Record 15 of Set 10 | tautira
# Processing Record 16 of Set 10 | tripoli
# Processing Record 17 of Set 10 | nanning
# Processing Record 18 of Set 10 | tromso
# Processing Record 19 of Set 10 | sobolevo
# Processing Record 20 of Set 10 | trindade
# Processing Record 21 of Set 10 | bulgan
# Processing Record 22 of Set 10 | tikapur
# Processing Record 23 of Set 10 | wassenberg
# Processing Record 24 of Set 10 | nuuk
# Processing Record 25 of Set 10 | kourou
# Processing Record 26 of Set 10 | severo-kurilsk
# Processing Record 27 of Set 10 | waipawa
# Processing Record 28 of Set 10 | tessalit
# Processing Record 29 of Set 10 | tamandare
# Processing Record 30 of Set 10 | mandali
# Processing Record 31 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 32 of Set 10 | tornio
# Processing Record 33 of Set 10 | gazanjyk
# Processing Record 34 of Set 10 | shasta lake
# Processing Record 35 of Set 10 | ahuimanu
# Processing Record 36 of Set 10 | cutzamala
# City not found. Skipping...
# Processing Record 37 of Set 10 | abha
# Processing Record 38 of Set 10 | pacific grove
# Processing Record 39 of Set 10 | bara
# Processing Record 40 of Set 10 | oktyabrskoye
# Processing Record 41 of Set 10 | calbuco
# Processing Record 42 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 43 of Set 10 | arman
# Processing Record 44 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 45 of Set 10 | nikita
# Processing Record 46 of Set 10 | tamiahua
# Processing Record 47 of Set 10 | mareeba
# Processing Record 48 of Set 10 | ribeira grande
# Processing Record 49 of Set 10 | smithers
# Processing Record 50 of Set 10 | saint-georges
# Processing Record 1 of Set 11 | filingue
# Processing Record 2 of Set 11 | portland
# Processing Record 3 of Set 11 | mahibadhoo
# Processing Record 4 of Set 11 | birao
# Processing Record 5 of Set 11 | lake havasu city
# Processing Record 6 of Set 11 | mae sai
# Processing Record 7 of Set 11 | zhetybay
# City not found. Skipping...
# Processing Record 8 of Set 11 | larap
# Processing Record 9 of Set 11 | margate
# Processing Record 10 of Set 11 | ngunguru
# Processing Record 11 of Set 11 | cortes
# Processing Record 12 of Set 11 | bridgeton
# Processing Record 13 of Set 11 | rudovci
# Processing Record 14 of Set 11 | san patricio
# Processing Record 15 of Set 11 | padang
# Processing Record 16 of Set 11 | ukiah
# Processing Record 17 of Set 11 | dzilam gonzalez
# Processing Record 18 of Set 11 | la asuncion
# Processing Record 19 of Set 11 | sibolga
# Processing Record 20 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 11 | san rafael del sur
# Processing Record 22 of Set 11 | oliveira dos brejinhos
# Processing Record 23 of Set 11 | hargeysa
# Processing Record 24 of Set 11 | nokha
# Processing Record 25 of Set 11 | whitehorse
# Processing Record 26 of Set 11 | maldonado
# Processing Record 27 of Set 11 | oranjemund
# Processing Record 28 of Set 11 | husavik
# Processing Record 29 of Set 11 | grindavik
# Processing Record 30 of Set 11 | xadani
# City not found. Skipping...
# Processing Record 31 of Set 11 | leeton
# Processing Record 32 of Set 11 | chifeng
# Processing Record 33 of Set 11 | kieta
# Processing Record 34 of Set 11 | cherrapunji
# Processing Record 35 of Set 11 | barraute
# Processing Record 36 of Set 11 | bossangoa
# Processing Record 37 of Set 11 | nyurba
# Processing Record 38 of Set 11 | umm kaddadah
# Processing Record 39 of Set 11 | salme
# Processing Record 40 of Set 11 | broome
# Processing Record 41 of Set 11 | uusikaupunki
# Processing Record 42 of Set 11 | qaqortoq
# Processing Record 43 of Set 11 | solano
# Processing Record 44 of Set 11 | bairiki
# Processing Record 45 of Set 11 | buraydah
# Processing Record 46 of Set 11 | mikkeli
# Processing Record 47 of Set 11 | bend
# Processing Record 48 of Set 11 | boa vista
# Processing Record 49 of Set 11 | atar
# Processing Record 50 of Set 11 | akyab
# Processing Record 1 of Set 12 | palmer
# Processing Record 2 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 3 of Set 12 | nago
# Processing Record 4 of Set 12 | barentu
# Processing Record 5 of Set 12 | yumen
# Processing Record 6 of Set 12 | urusha
# Processing Record 7 of Set 12 | tiznit
# Processing Record 8 of Set 12 | boddam
# Processing Record 9 of Set 12 | geraldton
# Processing Record 10 of Set 12 | aburi
# Processing Record 11 of Set 12 | hattiesburg
# Processing Record 12 of Set 12 | flin flon
# Processing Record 13 of Set 12 | clarence town
# Processing Record 14 of Set 12 | limbang
# Processing Record 15 of Set 12 | stromness
# Processing Record 16 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 12 | sulangan
# Processing Record 18 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 19 of Set 12 | araouane
# Processing Record 20 of Set 12 | darnah
# Processing Record 21 of Set 12 | kalmunai
# Processing Record 22 of Set 12 | bealanana
# Processing Record 23 of Set 12 | sai buri
# Processing Record 24 of Set 12 | mattawa
# Processing Record 25 of Set 12 | chara
# Processing Record 26 of Set 12 | korla
# Processing Record 27 of Set 12 | duz
# City not found. Skipping...
# Processing Record 28 of Set 12 | kalawit
# Processing Record 29 of Set 12 | santa cruz de tenerife
# Processing Record 30 of Set 12 | tishchenskoye
# Processing Record 31 of Set 12 | port-gentil
# Processing Record 32 of Set 12 | kestel
# Processing Record 33 of Set 12 | bilibino
# Processing Record 34 of Set 12 | gat
# Processing Record 35 of Set 12 | chancay
# Processing Record 36 of Set 12 | vila velha
# Processing Record 37 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 12 | shimoda
# Processing Record 39 of Set 12 | elizabethton
# Processing Record 40 of Set 12 | mosetse
# Processing Record 41 of Set 12 | talara
# Processing Record 42 of Set 12 | kangaatsiaq
# Processing Record 43 of Set 12 | togul
# Processing Record 44 of Set 12 | mount pleasant
# Processing Record 45 of Set 12 | jablah
# Processing Record 46 of Set 12 | amapa
# Processing Record 47 of Set 12 | ust-ilimsk
# Processing Record 48 of Set 12 | menongue
# Processing Record 49 of Set 12 | lagoa
# Processing Record 50 of Set 12 | victoria point
# Processing Record 1 of Set 13 | pouembout
# Processing Record 2 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 13 | salamiyah
# Processing Record 4 of Set 13 | san buenaventura
# Processing Record 5 of Set 13 | cidreira
# Processing Record 6 of Set 13 | mananara
# Processing Record 7 of Set 13 | olinda
# Processing Record 8 of Set 13 | same
# Processing Record 9 of Set 13 | riberalta
# Processing Record 10 of Set 13 | uspenskaya
# Processing Record 11 of Set 13 | gerash
# Processing Record 12 of Set 13 | meadow lake
# Processing Record 13 of Set 13 | vestmannaeyjar
# Processing Record 14 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 15 of Set 13 | ewa beach
# Processing Record 16 of Set 13 | jiwani
# Processing Record 17 of Set 13 | gari
# Processing Record 18 of Set 13 | bafq
# Processing Record 19 of Set 13 | loksa
# Processing Record 20 of Set 13 | komsomolskiy
# Processing Record 21 of Set 13 | melfort
# Processing Record 22 of Set 13 | trairi
# Processing Record 23 of Set 13 | orlik
# Processing Record 24 of Set 13 | asfi
# Processing Record 25 of Set 13 | parnamirim
# Processing Record 26 of Set 13 | karratha
# Processing Record 27 of Set 13 | duekoue
# Processing Record 28 of Set 13 | harnosand
# Processing Record 29 of Set 13 | ulaanbaatar
# Processing Record 30 of Set 13 | rockland
# Processing Record 31 of Set 13 | safaga
# Processing Record 32 of Set 13 | paamiut
# Processing Record 33 of Set 13 | dhidhdhoo
# Processing Record 34 of Set 13 | oga
# Processing Record 35 of Set 13 | dwarka
# Processing Record 36 of Set 13 | edd
# Processing Record 37 of Set 13 | sao filipe
# Processing Record 38 of Set 13 | la palma
# Processing Record 39 of Set 13 | san policarpo
# Processing Record 40 of Set 13 | ulladulla
# Processing Record 41 of Set 13 | kargat
# Processing Record 42 of Set 13 | nouadhibou
# Processing Record 43 of Set 13 | iracoubo
# Processing Record 44 of Set 13 | beberibe
# Processing Record 45 of Set 13 | zhenjiang
# Processing Record 46 of Set 13 | torbay
# Processing Record 47 of Set 13 | bull savanna
# Processing Record 48 of Set 13 | labrea
# Processing Record 49 of Set 13 | cuicatlan
# Processing Record 50 of Set 13 | matamoros
# Processing Record 1 of Set 14 | ayacucho
# Processing Record 2 of Set 14 | namyslow
# Processing Record 3 of Set 14 | henties bay
# Processing Record 4 of Set 14 | backnang
# Processing Record 5 of Set 14 | morro bay
# Processing Record 6 of Set 14 | nome
# Processing Record 7 of Set 14 | juneau
# Processing Record 8 of Set 14 | san cristobal
# Processing Record 9 of Set 14 | aksay
# Processing Record 10 of Set 14 | kulhudhuffushi
# Processing Record 11 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 12 of Set 14 | saldanha
# Processing Record 13 of Set 14 | lebyazhye
# Processing Record 14 of Set 14 | dapaong
# Processing Record 15 of Set 14 | port hedland
# Processing Record 16 of Set 14 | cabadiangan
# Processing Record 17 of Set 14 | erzin
# Processing Record 18 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 14 | rio grande city
# Processing Record 20 of Set 14 | mahbubabad
# Processing Record 21 of Set 14 | san juan evangelista
# Processing Record 22 of Set 14 | spas-demensk
# Processing Record 23 of Set 14 | koulamoutou
# Processing Record 24 of Set 14 | podporozhye
# Processing Record 25 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 26 of Set 14 | carutapera
# Processing Record 27 of Set 14 | yermish
# Processing Record 28 of Set 14 | sisimiut
# Processing Record 29 of Set 14 | neiafu
# Processing Record 30 of Set 14 | adana
# Processing Record 31 of Set 14 | palanga
# Processing Record 32 of Set 14 | thinadhoo
# Processing Record 33 of Set 14 | san jeronimo
# Processing Record 34 of Set 14 | poya
# Processing Record 35 of Set 14 | beian
# Processing Record 36 of Set 14 | saint george
# Processing Record 37 of Set 14 | jacareacanga
# Processing Record 38 of Set 14 | cururupu
# Processing Record 39 of Set 14 | farso
# Processing Record 40 of Set 14 | guajara
# Processing Record 41 of Set 14 | laguna de perlas
# Processing Record 42 of Set 14 | trinidad
# Processing Record 43 of Set 14 | ruwi
# Processing Record 44 of Set 14 | nalut
# Processing Record 45 of Set 14 | lichuan
# Processing Record 46 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 14 | nador
# Processing Record 48 of Set 14 | almaznyy
# Processing Record 49 of Set 14 | benghazi
# Processing Record 50 of Set 14 | rocky mountain house
# Processing Record 1 of Set 15 | kiknur
# Processing Record 2 of Set 15 | laguna
# Processing Record 3 of Set 15 | corinto
# Processing Record 4 of Set 15 | jiuquan
# Processing Record 5 of Set 15 | sedlcany
# Processing Record 6 of Set 15 | lincoln
# Processing Record 7 of Set 15 | manadhoo
# Processing Record 8 of Set 15 | tanout
# Processing Record 9 of Set 15 | nyuksenitsa
# Processing Record 10 of Set 15 | rohatyn
# Processing Record 11 of Set 15 | auki
# Processing Record 12 of Set 15 | asyut
# Processing Record 13 of Set 15 | davila
# Processing Record 14 of Set 15 | punta alta
# Processing Record 15 of Set 15 | linxi
# Processing Record 16 of Set 15 | sao geraldo do araguaia
# Processing Record 17 of Set 15 | ixtapa
# Processing Record 18 of Set 15 | angra
# City not found. Skipping...
# Processing Record 19 of Set 15 | windhoek
# Processing Record 20 of Set 15 | bonoua
# Processing Record 21 of Set 15 | makokou
# Processing Record 22 of Set 15 | mbandaka
# Processing Record 23 of Set 15 | zhanakorgan
# Processing Record 24 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 15 | jumla
# Processing Record 26 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 15 | shitanjing
# Processing Record 28 of Set 15 | mount isa
# Processing Record 29 of Set 15 | champerico
# Processing Record 30 of Set 15 | adrar
# Processing Record 31 of Set 15 | atasu
# Processing Record 32 of Set 15 | yeppoon
# Processing Record 33 of Set 15 | hede
# Processing Record 34 of Set 15 | noumea
# Processing Record 35 of Set 15 | leh
# Processing Record 36 of Set 15 | hay river
# Processing Record 37 of Set 15 | chongwe
# Processing Record 38 of Set 15 | petukhovo
# Processing Record 39 of Set 15 | biak
# Processing Record 40 of Set 15 | chapais
# Processing Record 41 of Set 15 | tomakivka
# Processing Record 42 of Set 15 | peleduy
# Processing Record 43 of Set 15 | taltal
# Processing Record 44 of Set 15 | temerloh
# Processing Record 45 of Set 15 | goryachegorsk
# Processing Record 46 of Set 15 | borsa
# Processing Record 47 of Set 15 | bunia
# Processing Record 48 of Set 15 | kozhevnikovo
# Processing Record 49 of Set 15 | mayumba
# Processing Record 50 of Set 15 | mishan
# Processing Record 1 of Set 16 | okato
# Processing Record 2 of Set 16 | mordovo
# Processing Record 3 of Set 16 | khailar
# Processing Record 4 of Set 16 | gulabpura
# Processing Record 5 of Set 16 | goure
# Processing Record 6 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 16 | talah
# City not found. Skipping...
# Processing Record 8 of Set 16 | ambilobe
# Processing Record 9 of Set 16 | rodez
# Processing Record 10 of Set 16 | cobija
# Processing Record 11 of Set 16 | porto walter
# Processing Record 12 of Set 16 | calama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country    Lat     Lng  Max Temp  Humidity  \
# 0                 Albany      US  42.60  -73.97     66.99        76
# 1           Punta Arenas      CL -53.15  -70.92     46.40        70
# 2                 Ankang      CN  32.68  109.02     53.47        66
# 3               Thompson      CA  55.74  -97.86     24.80        58
# 4              Ketchikan      US  55.34 -131.65     46.40        28
# 5                 Bethel      US  41.37  -73.41     62.01        97
# 6              Killybegs      IE  54.63   -8.45     48.00        93
# 7                Ushuaia      AR -54.80  -68.30     44.60        65
# 8  Los Llanos De Aridane      ES  28.66  -17.92     69.80        64
# 9              Busselton      AU -33.65  115.33     55.99        70
#
#    Cloudiness  Wind Speed Current description
# 0          68        1.99       broken clouds
# 1          75        8.05       broken clouds
# 2          79        2.75       broken clouds
# 3          75        8.05          light snow
# 4           1        3.36           clear sky
# 5          91        4.52     overcast clouds
# 6         100       18.01          light rain
# 7          75       12.75       broken clouds
# 8          40       10.29    scattered clouds
# 9           0        5.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
